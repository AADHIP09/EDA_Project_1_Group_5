# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from sklearn import datasets

# %%
df_3 = pd.read_csv('base_3_data.csv')
df_5 = pd.read_csv('base_5_data.csv')
df_5.head()
# Out:
#    Unnamed: 0       brand                 model color registration_date  year  \
# 0         723  alfa-romeo    Alfa Romeo Stelvio  blue           08/2019  2019
# 1         724  alfa-romeo  Alfa Romeo Giulietta  blue           10/2019  2019
# 2         725  alfa-romeo     Alfa Romeo Giulia  blue           02/2019  2019
# 3         726  alfa-romeo    Alfa Romeo Stelvio  blue           10/2019  2019
# 4         727  alfa-romeo    Alfa Romeo Stelvio  blue           05/2019  2019
#
#    price_in_euro  power_ps transmission_type fuel_type  \
# 0          41990       510         Automatic    Petrol
# 1          16995       120            Manual    Petrol
# 2          30880       209         Automatic    Diesel
# 3          30890       190         Automatic    Diesel
# 4          68900       510           Unknown    Petrol
#
#    fuel_consumption_l_100km  mileage_in_km
# 0                       9.2       199000.0
# 1                       7.4        49700.0
# 2                       5.5       129357.0
# 3                       6.1        82239.0
# 4                       9.8         7000.0

# %%
Year2021_df = df_3.loc[df_3["year"] == 2021, :]
Year2022_df = df_3.loc[df_3["year"] == 2022, :]
Year2023_df = df_3.loc[df_3["year"] == 2023, :]

# %%
Clean2021_df = Year2021_df["fuel_type"].replace({'Diesel Hybrid' : 'Hybrid', 'Unknown' : 'Other', 'LPG': 'Other', 'CNG' : 'Other'})
data1 = Clean2021_df.value_counts()

data1 
Chart2021 = data1.plot(kind="pie", autopct= "%1.1f%%", figsize=(6,6))
plt.title ("Percentage of Cars sold by Fuel Type in 2021")
# Out:
# Text(0.5, 1.0, 'Percentage of Cars sold by Fuel Type in 2021')

# %%
Clean2022_df = Year2022_df["fuel_type"].replace({'Diesel Hybrid' : 'Hybrid', 'Unknown' : 'Other', 'LPG': 'Other', 'CNG' : 'Other'})
data1 = Clean2022_df.value_counts()

data1 
Chart2022 = data1.plot(kind="pie", autopct= "%1.1f%%", figsize=(6,6))
plt.title ("Percentage of Cars sold by Fuel Type in 2022")
# Out:
# Text(0.5, 1.0, 'Percentage of Cars sold by Fuel Type in 2022')

# %%
Clean2023_df = Year2023_df["fuel_type"].replace({'Diesel Hybrid' : 'Hybrid', 'Unknown' : 'Other', 'LPG': 'Other', 'CNG' : 'Other'})
data1 = Clean2023_df.value_counts()

data1 
Chart2023 = data1.plot(kind="pie", autopct= "%1.1f%%", figsize=(6,6))
plt.title ("Percentage of Cars sold by Fuel Type in 2023")
# Out:
# Text(0.5, 1.0, 'Percentage of Cars sold by Fuel Type in 2023')

# %%
grouped_df = df_5.groupby('year')["transmission_type"].count()
grouped_df
# Out:
# year
# 2019    25331
# 2020    15140
# 2021    12081
# 2022    16738
# 2023    19326
# Name: transmission_type, dtype: int64

# %%
grouped_df.plot(kind = "line", x='year', y='transmission_type', figsize=(12,10))
# Out:
# <Axes: xlabel='year'>

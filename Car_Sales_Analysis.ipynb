# %%
import pandas as pd
from pathlib import Path

# %%
car_sales1 = Path('Car_sales_2021_df.xlsx')
car_sales2 = Path('Imputed_data.csv')

# %%
car_df1 = pd.read_excel(car_sales1)
car_df2 = pd.read_csv(car_sales2)

# %%
# Combine the data into a single dataset.  
merged_df = pd.merge(car_df1, car_df2, how="outer", on=["Model", "Model"])
merged_df.tail(50)
# Out:
#     Make_x    Model Body Type  Jan  Feb  Mar  Apr  May  Jun  Jul  ...  \
# 647    NaN     lon2       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 648    NaN     lon2       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 649    NaN     lon3       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 650    NaN     lon3       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 651    NaN   L300-2       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 652    NaN     L300       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 653    NaN       xA       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 654    NaN       xB       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 655    NaN     Baja       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 656    NaN     XL-7       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 657    NaN   Vitara       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 658    NaN     Aeno       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# ...

# %% [raw]
# merged_df.to_excel("Merged_2021_df.xlsx", index=False)

# %%
car_df1
# Out:
#       Make      Model     Body Type  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  \
# 0    Acura        ILX         Sedan   62   65  124  116   93   73   70   68
# 1    Acura        MDX           SUV   93  389  782  611  550  501  347  516
# 2    Acura        NSX  2 Door Coupe    0    2    3    5    5    1    1    2
# 3    Acura        RDX           SUV  443  466  650  552  607  738  747  720
# 4    Acura        RLX         Sedan    0    0    1    0    0    0    0    0
# ..     ...        ...           ...  ...  ...  ...  ...  ...  ...  ...  ...
# 284  Volvo  60-Series           SUV   98   98  110    0  134   81  121  157
# 285  Volvo  90-Series           SUV    7    7    8   15   19   12   15   19
# 286  Volvo       XC40           SUV  222  222  250  369  477  289  252  327
# 287  Volvo       XC60           SUV  155  155  174  241  312  189  395  511
# 288  Volvo       XC90           SUV  190  190  214  261  338  205  281  364
#
#      Sep  Oct  Nov  Dec  Total Sales
# ...

# %%
car_df.iloc[:, 2:] = car_df.iloc[:, 2:].replace('[\$,]', '', regex=True).replace('-', '0', regex=True).astype(int)

car_df['Total Sales'] = car_df.iloc[:, 2:].sum(axis=1)

# %%
car_df
# Out:
#       Make      Model  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  \
# 0    Acura        ILX   62   65  124  116   93   73   70   68   58   59   39
# 1    Acura        MDX   93  389  782  611  550  501  347  516  309  406  303
# 2    Acura        NSX    0    2    3    5    5    1    1    2    3    0    1
# 3    Acura        RDX  443  466  650  552  607  738  747  720  788  854  661
# 4    Acura        RLX    0    0    1    0    0    0    0    0    1    0    0
# ..     ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 286  Volvo  60-Series   98   98  110    0  134   81  121  157   95  122  158
# 287  Volvo  90-Series    7    7    8   15   19   12   15   19   12   23   29
# 288  Volvo       XC40  222  222  250  369  477  289  252  327  198  224  290
# 289  Volvo       XC60  155  155  174  241  312  189  395  511  309  311  402
# 290  Volvo       XC90  190  190  214  261  338  205  281  364  220  192  249
#
#      Dec  Total Sales
# ...

# %%
car_df.to_excel("car_sales_2021_df.xlsx", index=False)

# %%
car_df
# Out:
#       Make      Model  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  \
# 0    Acura        ILX   62   65  124  116   93   73   70   68   58   59   39
# 1    Acura        MDX   93  389  782  611  550  501  347  516  309  406  303
# 2    Acura        NSX    0    2    3    5    5    1    1    2    3    0    1
# 3    Acura        RDX  443  466  650  552  607  738  747  720  788  854  661
# 4    Acura        RLX    0    0    1    0    0    0    0    0    1    0    0
# ..     ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 286  Volvo  60-Series   98   98  110    0  134   81  121  157   95  122  158
# 287  Volvo  90-Series    7    7    8   15   19   12   15   19   12   23   29
# 288  Volvo       XC40  222  222  250  369  477  289  252  327  198  224  290
# 289  Volvo       XC60  155  155  174  241  312  189  395  511  309  311  402
# 290  Volvo       XC90  190  190  214  261  338  205  281  364  220  192  249
#
#      Dec  Total Sales
# ...

# %%
car_sales_2021_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 car_sales_2021_df
#
# NameError: name 'car_sales_2021_df' is not defined

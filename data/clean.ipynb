# %%
import pandas as pd
import numpy as np

# %%
sale_df = pd.read_csv("car_sale.csv")
profil_df = pd.read_csv("cars_data.csv")
model_df = pd.read_csv("2021_model.csv")

# %%
sale_df.head()
# Out:
#        Model    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep  \
# 0  Acura ILX    914    819  1,253  1,312  1,842  2,093  1,957  1,018    422
# 1  Acura MDX  2,827  5,379  8,782  7,685  7,041  5,077  4,290  4,632  2,101
# 2  Acura NSX      6      4      7     12     15     16      7     31     20
# 3  Acura RDX  3,386  3,520  4,706  4,576  5,864  5,638  5,789  5,842  4,915
# 4  Acura RLX     59     43     42     26     16     12      7      1      3
#
#      Oct    Nov    Dec      Sum
# 0    209    700  1,361  13900.0
# 1  3,157  3,551  5,535  60057.0
# 2      5      -      1    124.0
# 3  5,313  3,976  3,488  57013.0
# 4      3      -      2    214.0

# %%
profil_df
# Out:
#       Make                    Model   Type  Origin DriveTrain         MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945.00
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820.00
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990.00
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195.00
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755.00
# ..     ...                      ...    ...     ...        ...          ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565.00
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565.00
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210.00
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135.00
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145.00
#
#          Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 0    $33,337.00          3.5        6.0         265        17           23
# 1    $21,761.00          2.0        4.0         200        24           31
# 2    $24,647.00          2.4        4.0         200        22           29
# 3    $30,299.00          3.2        6.0         270        20           28
# 4    $39,014.00          3.5        6.0         225        18           24
# ..           ...         ...        ...         ...       ...          ...
# 423  $38,203.00          2.4        5.0         197        21           28
# 424  $40,083.00          2.3        5.0         242        20           26
# 425  $42,573.00          2.9        6.0         268        19           26
# 426  $24,641.00          1.9        4.0         170        22           29
# 427  $33,112.00          2.5        5.0         208        20           27
#
#      Weight  Wheelbase  Length
# 0      4451        106     189
# 1      2778        101     172
# 2      3230        105     183
# 3      3575        108     186
# 4      3880        115     197
# ..      ...        ...     ...
# 423    3450        105     186
# 424    3450        105     186
# 425    3653        110     190
# 426    2822        101     180
# 427    3823        109     186
#
# [428 rows x 15 columns]

# %%
sale_df[['Make',"Model"]] = sale_df["Model"].str.split(" ", 1, expand=True)
# Out:
# /var/folders/98/7w_ymnx92yjb0k5p9khzwsrw0000gn/T/ipykernel_60337/2414196345.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   sale_df[['Make',"Model"]] = sale_df["Model"].str.split(" ", 1, expand=True)

# %%
first_column = sale_df.pop('Make')
sale_df.insert(0, 'Make', first_column)

# %%
sale_df = sale_df[["Make","Model","Sum"]]

# %%
profil_df["Make"].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
sale_df["Make"].value_counts()
# Out:
# Toyota           21
# Ford             17
# Audi             17
# BMW              17
# Mercedes-Benz    17
# Chevrolet        17
# Nissan           16
# Kia              15
# Hyundai          14
# Honda            11
# Lexus            11
# Mazda             9
# Volkswagen        9
# Jeep              9
# Subaru            8
# Cadillac          8
# Dodge             7
# Jaguar            7
# Land              7
# Porsche           6
# Lincoln           6
# Acura             6
# Infiniti          6
# GMC               6
# Buick             6
# Volvo             6
# Mitsubishi        5
# Genesis           5
# Fiat              4
# Tesla             4
# Chrysler          4
# Alfa              3
# Ram               3
# Mini              2
# Name: Make, dtype: int64

# %%
merge_df = pd.merge(profil_df, sale_df, on=["Make","Model"], how="outer")
merge_df.head()
# Out:
#     Make           Model   Type Origin DriveTrain         MSRP      Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945.00   $33,337.00
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820.00   $21,761.00
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990.00   $24,647.00
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195.00   $30,299.00
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755.00   $39,014.00
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length      Sum
# 0      106.0   189.0  60057.0
# 1      101.0   172.0      NaN
# 2      105.0   183.0      NaN
# 3      108.0   186.0      NaN
# 4      115.0   197.0      NaN

# %%
merge_df. dropna()
# Out:
#          Make         Model   Type Origin DriveTrain         MSRP  \
# 0       Acura           MDX    SUV   Asia        All  $36,945.00
# 55   Cadillac      Escalade    SUV    USA      Front  $52,795.00
# 104  Chrysler      Pacifica  Wagon    USA       Rear  $31,230.00
# 364    Subaru       Outback  Wagon   Asia        All  $23,895.00
# 377    Toyota  Land Cruiser    SUV   Asia        All  $54,765.00
# 378    Toyota          RAV4    SUV   Asia        All  $20,290.00
# 397    Toyota        Tacoma  Truck   Asia       Rear  $12,800.00
#
#          Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 0    $33,337.00          3.5        6.0       265.0      17.0         23.0
# 55   $48,377.00          5.3        8.0       295.0      14.0         18.0
# 104  $28,725.00          3.5        6.0       250.0      17.0         23.0
# 364  $21,773.00          2.5        4.0       165.0      21.0         28.0
# 377  $47,986.00          4.7        8.0       325.0      13.0         17.0
# 378  $18,553.00          2.4        4.0       161.0      22.0         27.0
# 397  $11,879.00          2.4        4.0       142.0      22.0         27.0
#
#      Weight  Wheelbase  Length       Sum
# 0    4451.0      106.0   189.0   60057.0
# 55   5367.0      116.0   199.0   40504.0
# 104  4675.0      116.0   199.0   74970.0
# 364  3430.0      104.0   187.0  154623.0
# 377  5390.0      112.0   193.0    3711.0
# 378  3119.0       98.0   167.0  407739.0
# 397  2750.0      103.0   191.0  252490.0

# %%
import pandas as pd
from pathlib import Path

# %%
data = Path("data.csv")

# %%
og_data = pd.read_csv(data)
og_data.head()
# Out:
#    Unnamed: 0       brand              model  color registration_date  year  \
# 0           0  alfa-romeo     Alfa Romeo GTV    red            Oct-95  1995
# 1           1  alfa-romeo     Alfa Romeo 164  black            Feb-95  1995
# 2           2  alfa-romeo  Alfa Romeo Spider  black            Feb-95  1995
# 3           3  alfa-romeo  Alfa Romeo Spider  black            Jul-95  1995
# 4           4  alfa-romeo     Alfa Romeo 164    red            Nov-96  1996
#
#   price_in_euro power_kw power_ps transmission_type fuel_type  \
# 0          1300      148      201            Manual    Petrol
# 1         24900      191      260            Manual    Petrol
# 2          5900      110      150           Unknown    Petrol
# 3          4900      110      150            Manual    Petrol
# 4         17950      132      179            Manual    Petrol
#
#   fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 0            10,9 l/100 km              260 g/km       160500.0
# 1                      NaN                #NAME?       190000.0
# 2                      NaN                #NAME?       129000.0
# 3             9,5 l/100 km              225 g/km       189500.0
# 4             7,2 l/100 km                #NAME?        96127.0
#
#                        offer_description
# 0                              2.0 V6 TB
# 1                    Q4 Allrad, 3.2L GTA
# 2                          ALFA ROME 916
# 3                   2.0 16V Twin Spark L
# 4  3.0i Super V6, absoluter Topzustand !

# %%
# Columns we're interested in:
og_data = og_data[['brand','model','color','registration_date','year','price_in_euro','power_ps',
                   'transmission_type','fuel_type','fuel_consumption_l_100km','mileage_in_km']]
og_data
# Out:
#              brand              model  color registration_date  year  \
# 0       alfa-romeo     Alfa Romeo GTV    red            Oct-95  1995
# 1       alfa-romeo     Alfa Romeo 164  black            Feb-95  1995
# 2       alfa-romeo  Alfa Romeo Spider  black            Feb-95  1995
# 3       alfa-romeo  Alfa Romeo Spider  black            Jul-95  1995
# 4       alfa-romeo     Alfa Romeo 164    red            Nov-96  1996
# ...            ...                ...    ...               ...   ...
# 251074       volvo         Volvo XC40  white            Apr-23  2023
# 251075       volvo         Volvo XC90  white            Mar-23  2023
# 251076       volvo          Volvo V60  white            May-23  2023
# 251077       volvo         Volvo XC40  white            May-23  2023
# 251078       volvo         Volvo XC40   gold            Mar-23  2023
#
#        price_in_euro power_ps transmission_type fuel_type  \
# 0               1300      201            Manual    Petrol
# 1              24900      260            Manual    Petrol
# 2               5900      150           Unknown    Petrol
# 3               4900      150            Manual    Petrol
# 4              17950      179            Manual    Petrol
# ...              ...      ...               ...       ...
# 251074         57990      261         Automatic    Hybrid
# 251075         89690      235         Automatic    Diesel
# 251076         61521      197         Automatic    Diesel
# 251077         57890      179         Automatic    Hybrid
# 251078         52900      218         Automatic  Electric
#
#        fuel_consumption_l_100km  mileage_in_km
# 0                 10,9 l/100 km       160500.0
# 1                           NaN       190000.0
# 2                           NaN       129000.0
# 3                  9,5 l/100 km       189500.0
# 4                  7,2 l/100 km        96127.0
# ...                         ...            ...
# 251074                      NaN         1229.0
# 251075             7,6 l/100 km         4900.0
# 251076             4,7 l/100 km         1531.0
# 251077                      NaN         1500.0
# 251078                      NaN           50.0
#
# [251079 rows x 11 columns]

# %%
og_data.dtypes
# Out:
# brand                        object
# model                        object
# color                        object
# registration_date            object
# year                         object
# price_in_euro                object
# power_ps                     object
# transmission_type            object
# fuel_type                    object
# fuel_consumption_l_100km     object
# mileage_in_km               float64
# dtype: object

# %%
og_data.count()
# Out:
# brand                       251079
# model                       251079
# color                       250913
# registration_date           251075
# year                        251079
# price_in_euro               251079
# power_ps                    250950
# transmission_type           251079
# fuel_type                   251079
# fuel_consumption_l_100km    224206
# mileage_in_km               250927
# dtype: int64

# %%
og_data1 = og_data.dropna()
og_data1.count()
# Out:
# brand                       223842
# model                       223842
# color                       223842
# registration_date           223842
# year                        223842
# price_in_euro               223842
# power_ps                    223842
# transmission_type           223842
# fuel_type                   223842
# fuel_consumption_l_100km    223842
# mileage_in_km               223842
# dtype: int64

# %%
og_data1.head(20)
# Out:
#          brand              model   color registration_date  year  \
# 0   alfa-romeo     Alfa Romeo GTV     red            Oct-95  1995
# 3   alfa-romeo  Alfa Romeo Spider   black            Jul-95  1995
# 4   alfa-romeo     Alfa Romeo 164     red            Nov-96  1996
# 5   alfa-romeo  Alfa Romeo Spider     red            Apr-96  1996
# 6   alfa-romeo     Alfa Romeo 145     red            Dec-96  1996
# 7   alfa-romeo     Alfa Romeo 164   black            Jul-96  1996
# 8   alfa-romeo  Alfa Romeo Spider   black            Jul-96  1996
# 9   alfa-romeo  Alfa Romeo Spider   black            Jan-96  1996
# 10  alfa-romeo  Alfa Romeo Spider  silver            Feb-96  1996
# 11  alfa-romeo  Alfa Romeo Spider  silver            Oct-96  1996
# 12  alfa-romeo     Alfa Romeo GTV  silver            Apr-96  1996
# 13  alfa-romeo     Alfa Romeo GTV    grey            May-97  1997
# 14  alfa-romeo     Alfa Romeo 155    grey            Jun-97  1997
# 15  alfa-romeo     Alfa Romeo GTV     red            Oct-97  1997
# 16  alfa-romeo     Alfa Romeo GTV     red            Mar-97  1997
# 17  alfa-romeo     Alfa Romeo GTV     red            Jan-97  1997
# 19  alfa-romeo     Alfa Romeo 145     red            Mar-97  1997
# 20  alfa-romeo  Alfa Romeo Spider     red            Feb-97  1997
# 21  alfa-romeo  Alfa Romeo Spider     red            Apr-97  1997
# 23  alfa-romeo     Alfa Romeo GTV   black            Jun-97  1997
#
#    price_in_euro power_ps transmission_type fuel_type  \
# 0           1300      201            Manual    Petrol
# 3           4900      150            Manual    Petrol
# 4          17950      179            Manual    Petrol
# 5           7900      150            Manual    Petrol
# 6           3500      150            Manual    Petrol
# 7           5500      179            Manual    Petrol
# 8           8990      192            Manual    Petrol
# 9           6976      150            Manual    Petrol
# 10          5499      192            Manual    Petrol
# 11          8499      150            Manual    Petrol
# 12          2290      150            Manual    Petrol
# 13         15800      220            Manual    Petrol
# 14          7950      120            Manual    Petrol
# 15          1300      201            Manual    Petrol
# 16          6900      150            Manual    Petrol
# 17         16900      220            Manual    Petrol
# 19         11990      120            Manual    Petrol
# 20         11900      150            Manual    Petrol
# 21          5800      150            Manual    Petrol
# 23          5777      220            Manual    Petrol
#
#    fuel_consumption_l_100km  mileage_in_km
# 0             10,9 l/100 km       160500.0
# 3              9,5 l/100 km       189500.0
# 4              7,2 l/100 km        96127.0
# 5              9,5 l/100 km        47307.0
# 6              8,8 l/100 km       230000.0
# 7             13,4 l/100 km       168000.0
# 8               11 l/100 km       168600.0
# 9              9,2 l/100 km        99000.0
# 10            11,1 l/100 km       157000.0
# 11             9,5 l/100 km        15550.0
# 12             9,5 l/100 km       333500.0
# 13            11,7 l/100 km       177000.0
# 14             8,4 l/100 km       101726.0
# 15            10,9 l/100 km       178000.0
# 16             9,2 l/100 km       110313.0
# 17            11,7 l/100 km       174000.0
# 19             8,2 l/100 km       124963.0
# 20             9,2 l/100 km        39000.0
# 21             9,5 l/100 km       124112.0
# 23            11,7 l/100 km       125000.0

# %%
og_data1['fuel_consumption_l_100km']
# Out:
# 0         10,9 l/100 km
# 3          9,5 l/100 km
# 4          7,2 l/100 km
# 5          9,5 l/100 km
# 6          8,8 l/100 km
#               ...
# 251071     7,4 l/100 km
# 251072     5,6 l/100 km
# 251073     5,6 l/100 km
# 251075     7,6 l/100 km
# 251076     4,7 l/100 km
# Name: fuel_consumption_l_100km, Length: 223842, dtype: object

# %%
og_data1['fuel_consumption_l_100km'] = og_data1['fuel_consumption_l_100km'].str.replace(',', '').str.extract(r'(\d+\.\d+|\d+)').astype(float)
# Out:
# C:\Users\sahuja\AppData\Local\Temp\ipykernel_6328\1232506774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   og_data1['fuel_consumption_l_100km'] = og_data1['fuel_consumption_l_100km'].str.replace(',', '').str.extract(r'(\d+\.\d+|\d+)').astype(float)

# %%
og_data1['fuel_consumption_l_100km']
# Out:
# 0         109.0
# 3          95.0
# 4          72.0
# 5          95.0
# 6          88.0
#           ...
# 251071     74.0
# 251072     56.0
# 251073     56.0
# 251075     76.0
# 251076     47.0
# Name: fuel_consumption_l_100km, Length: 223842, dtype: float64

# %%
# Dropping numeric values from the fuel_type 
og_data1 = og_data1[~og_data1['fuel_type'].str.contains(r'\d')]

# %%
# Dropping other unwanted values from the fuel_type 
values_to_drop = ['Automatic', 'Manual', 'Other', 'Unknown']

og_data1 = og_data1[~og_data1['fuel_type'].isin(values_to_drop)]

# %%
# Dropping rows with unknown values from the transmission_type 
values_to_drop1 = ['Unknown']

og_data1 = og_data1[~og_data1['transmission_type'].isin(values_to_drop1)]

# %%
og_data1.to_csv('clean_data2.csv', index=False)

# %%
# Dropping rows with un-realistic fuel consumption figures from the column fuel_consumption_l_100km

og_data1 = og_data1[og_data1['fuel_consumption_l_100km'] <= 30]

# %%
# Saving new clean csv 
og_data1.to_csv('clean_data3.csv', index=False)

# %%
og_data1.count()
# Out:
# brand                       25181
# model                       25181
# color                       25181
# registration_date           25181
# year                        25181
# price_in_euro               25181
# power_ps                    25181
# transmission_type           25181
# fuel_type                   25181
# fuel_consumption_l_100km    25181
# mileage_in_km               25181
# dtype: int64
